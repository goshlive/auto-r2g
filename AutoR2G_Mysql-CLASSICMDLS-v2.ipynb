# %%
from collections import Counter
import mysql.connector
from mysql.connector import Error
import csv
import re
from neo4j import GraphDatabase
import pandas as pd
import numpy as np
from pandas.errors import ParserError

import math
import warnings
warnings.filterwarnings('ignore') # setting ignore as a parameter

# %%
class Neo4jDB:
    
    def __init__(self, uri, user, pwd=''):
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        try:
            self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__user, self.__pwd))
        except Exception as e:
            print("Failed to create the driver:", e)
        
    def close(self):
        if self.__driver is not None:
            self.__driver.close()
        
    def query(self, query, parameters=None, db=None):
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        try: 
            session = self.__driver.session(database=db) if db is not None else self.__driver.session() 
            response = list(session.run(query, parameters))
        except Exception as e:
            print("Query failed:", e)
        finally: 
            if session is not None:
                session.close()
        return response
    
neoConn = Neo4jDB(uri="bolt://localhost:7687", user="")

# %%
host = 'localhost'
schema = 'classicmodels'
user = 'root'
password = '<put password here>'

# %%
try:
    connection = mysql.connector.connect(host=host, database=schema, user=user, password=password)
    
    if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)

except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Connected to MySQL Server version  8.0.29
# You're connected to database:  ('classicmodels',)

# %%
def _clear_all(commit):
    if commit:
        query='''MATCH (n)
        DETACH DELETE n
        RETURN count(*) AS total'''
        return neoConn.query(query)

# %%
def get_dict(tables, keys):
    ref = {}
    for i in range(len(tables)):
        table = tables[i]
        if ref.get(table):
            ref[table] += ','+str(keys[i])
        else:
            ref[table] = str(keys[i])
    
    return ref

# %%
def populate_obj(name, df, excludes):
    header = list(df.columns)
    
    obj = '('+name.lower()+':'+name.capitalize()+'{'
    first = True
    for h in header:
        if h not in excludes:
            if first:
                first = False
            else:
                obj +=','
            obj += h+': row.'+h
        
    obj +='})'
    return obj

# %%
def _read_csv(table, s, e):
    file = 'db.localhost/{}/{}.csv'.format(schema, table)
    #print("file: {}".format(file))
    return pd.read_csv (file, sep = s, encoding = e)

# %%
def _get_ref_node(table, ref_table):
    #print("table:{}, ref_table:{}".format(table, ref_table))
    rtn = ref_table.lower()
    if table and ref_table:
        if table.strip() == ref_table.strip():
            return "{}_".format(ref_table.lower())
            
    return rtn

# %%
def generate_single_graph(m, df_logs, commit):
    st = time.time()
    table = m.get('table')    
    print("\n\n===> Processing records for Table '{}'".format(table))
    if not commit:
        print(m)    

    records = _read_csv(table, ';', 'utf-8')

    query = '''UNWIND $rows AS row \nCREATE ''' + populate_obj(table.lower(), records, []) + '''\nRETURN count(*) as total'''

    print(f'table[{table}], records[{len(records)}]')
    df_logs = _add_row(df_logs, table, ref_tables='', no_records=len(records), no_rels=0, no_nodes=1)
    
    if not commit:
        print(query)
    else:
        neoConn.query(query, parameters = {'rows': records.to_dict('records')})
        
    return df_logs

# %%
def generate_joined_graph(m, s, df_logs, commit):
    table = m.get('table')
    print("\n\n===> Processing records for Table '{}'".format(table))
    if not commit:
        print(m)    

    records = _read_csv(table, ';', 'utf-8')

    pri_key = m.get('pri_key').split(',')    
    for_keys = m.get('for_keys').split(',')    
    # print(for_keys)
    ref_tables = m.get('ref_tables').split(',')  
    # print(ref_tables)
    ref_keys = m.get('ref_keys').split(',')    
    # print(ref_keys)
    ref = get_dict(ref_tables, ref_keys)
    # print(ref)
    
    #if sorted(pri_key) == sorted(for_keys):
    #    query = '''UNWIND $rows AS row\nCREATE ''' + populate_obj(table.lower(), records, []) +'''\n'''
    #else:
    #    query = '''UNWIND $rows AS row\nCREATE ''' + populate_obj(table.lower(), records, for_keys) +'''\n'''    
    #include ids
    query = '''UNWIND $rows AS row\nCREATE ''' + populate_obj(table.lower(), records, []) +'''\n'''
    
    start = 0
    end = 0
    no_edges = 0
    for ref_table, ids in ref.items():
        
        ref_ids = ids.split(',')
        # print(ref_table)
        # print(ref_ids)

        end = start+len(ref_ids)
        fk = for_keys[start:end]

        #skip, if it is a cyclic table
        if s and ref_table in s:
            print("********** Table '{}' is a cyclic referenced by Table '{}'..skipped it *********".format(ref_table, table))
            start = end
            continue
        
        print("Processing reference Table '{}' ...".format(ref_table))
        query += '''\nWITH distinct row, ''' + table.lower()
        
        no_edges += 1
        
        prev_fk = None
        duplicate = False
        uwind = {}
        for i in range(len(fk)):
            if (prev_fk == ref_ids[i]):
                uwind[i] = '''\nUNWIND row.''' + fk[i] + ''' AS _''' + fk[i]
            else:
                query += '''\nUNWIND row.''' + fk[i] + ''' AS _''' + fk[i]
            prev_fk = ref_ids[i]

        if len(uwind) > 0:
            for i in range(len(fk)):
                if i>0:
                    query += '''\nWITH distinct row, ''' + table.lower()
                    query += uwind.get(i)
                ref = _get_ref_node(table, ref_table)
                query += '''\nMATCH (''' +ref+ ''':'''+ ref_table.capitalize() +''' {'''
                query += ref_ids[i] + ''': _'''+fk[i]
                query += '''})\nMERGE ('''+table.lower()+''')-[:'''+ table.upper() + '''_''' + ref_table.upper() +''']->('''+ref+''')'''
        else:
            ref = _get_ref_node(table, ref_table)
            query += '''\nMATCH (''' + ref + ''':'''+ ref_table.capitalize() +''' {'''
            first = True
            for i in range(len(fk)):
                if not first:
                    query += ''','''
                else:
                    first = False
                query += ref_ids[i] + ''': _'''+fk[i]
            query += '''})\nMERGE ('''+table.lower()+''')-[:'''+ table.upper() + '''_''' + ref_table.upper() +''']->('''+ref+''')'''

        start = end

    query += '''\nRETURN count(*) AS total'''

    df_logs = _add_row(df_logs, table, ref_tables=ref_tables, no_records=len(records), no_rels=len(ref_tables), no_nodes=1, no_edges=no_edges)
    
    if not commit:
        print(query)
    else:
        neoConn.query(query, parameters = {'rows': records.to_dict('records')})    
        
    return df_logs

# %%
def generate_edges(m, r, df_logs, commit):
    table = m.get('table')
    print("\n\n===> Creating additional Edges between Table '{}' and Table(s) '{}' ".format(table, r))
    if not commit:
        print(m)
        print(r)

    records = _read_csv(table, ';', 'utf-8')

    pri_key = m.get('pri_key').split(',')    
    for_keys = m.get('for_keys').split(',')    
    # print(for_keys)
    ref_tables = m.get('ref_tables').split(',')  
    # print(ref_tables)
    ref_keys = m.get('ref_keys').split(',')    
    # print(ref_keys)
    ref = get_dict(ref_tables, ref_keys)
    # print(ref)
    
    query = '''UNWIND $rows AS row'''
    for prim in pri_key:
        query += '''\nUNWIND row.''' + prim + ''' AS _''' + prim
    
    query += '''\nMATCH (''' + table.lower() + ''':'''+ table.capitalize() +''' {'''
    first = True
    for i in range(len(pri_key)):
        if not first:
            query += ''','''
        else:
            first = False
        query += pri_key[i] + ''': _'''+pri_key[i]
    query += '''})'''

    start = 0
    end = 0
    no_edges = 0
    for ref_table, ids in ref.items():
        
        ref_ids = ids.split(',')
        #print(ref_table)
        #print(ref_ids)

        end = start+len(ref_ids)
        fk = for_keys[start:end]
        
        if ref_table not in r:
            print('********** Skipping table {} **********'.format(ref_table))
            start = end
            continue
                
        print("Creating an Edge from Table '{}' --> Table '{}' ...".format(table, ref_table))
        query += '''\nWITH distinct row, ''' + table.lower()
        
        no_edges += 1
        
        prev_fk = None
        duplicate = False
        uwind = {}
        for i in range(len(fk)):
            if (prev_fk == ref_ids[i]):
                uwind[i] = '''\nUNWIND row.''' + fk[i] + ''' AS _''' + fk[i]
            else:
                query += '''\nUNWIND row.''' + fk[i] + ''' AS _''' + fk[i]
            prev_fk = ref_ids[i]

        if len(uwind) > 0:
            for i in range(len(fk)):
                if i>0:
                    query += '''\nWITH distinct row, ''' + table.lower()
                    query += uwind.get(i)
                ref = _get_ref_node(table, ref_table)
                query += '''\nMATCH (''' + ref + ''':'''+ ref_table.capitalize() +''' {'''
                query += ref_ids[i] + ''': _'''+fk[i]
                query += '''})\nMERGE ('''+table.lower()+''')-[:'''+ table.upper() + '''_''' + ref_table.upper() +''']->('''+ref+''')'''
        else:
            ref = _get_ref_node(table, ref_table)
            query += '''\nMATCH (''' + ref + ''':'''+ ref_table.capitalize() +''' {'''
            first = True
            for i in range(len(fk)):
                if not first:
                    query += ''','''
                else:
                    first = False
                query += ref_ids[i] + ''': _'''+fk[i]
            query += '''})\nMERGE ('''+table.lower()+''')-[:'''+ table.upper() + '''_''' + ref_table.upper() +''']->('''+ref+''')'''

        start = end

    query += '''\nRETURN count(*) AS total'''

    df_logs = _add_row(df_logs, table, ref_tables=ref_tables, no_records=len(records), no_rels=len(ref_tables), no_edges=no_edges)
        
    if not commit:
        print(query)
    else:
        neoConn.query(query, parameters = {'rows': records.to_dict('records')})    
        
    return df_logs

# %%
def get_ddl(c1, table):
    q2 = "SHOW CREATE TABLE %s;" % table
    c1.execute(q2)
    result = c1.fetchone()
    return list(result.values())[1]

# %%
def get_metadata(c1, table):
    ddl = get_ddl(c1, table)
    
    prog = re.compile('CREATE TABLE.*?`(.*).*?`\s\(', re.IGNORECASE)
    table = prog.findall(ddl)[0]

    prog = re.compile('PRIMARY KEY\s\S(.*)(?=\))', re.IGNORECASE)
    pri_key = prog.findall(ddl)[0].replace('`', '')

    prog = re.compile('FOREIGN KEY.*?\(`(.*).*?`\)\sREFERENCES', re.IGNORECASE)
    for_keys = prog.findall(ddl)
    for_keys = ",".join(for_keys)

    prog = re.compile('REFERENCES.*?`(.*).*?`\s', re.IGNORECASE)
    ref_tables = prog.findall(ddl)
    ref_tables = ",".join(ref_tables)

    prog = re.compile('REFERENCES.*?\(`(.*).*?`\)', re.IGNORECASE)
    ref_keys = prog.findall(ddl)
    ref_keys = ",".join(ref_keys)
    
    return {'table':table, 'pri_key':pri_key, 'for_keys': for_keys, 'ref_tables':ref_tables, 'ref_keys':ref_keys}

# %%
def _compute_out(data):
    return len(data.split(','))        

def _compute_in(key, unsorted_data):
    counter = 0
    for k, v in unsorted_data.items():
        if k != key and key in v:
            dependents = v.split(',')
            for d in dependents:
                if d.strip() == key:
                    counter += 1
    return counter
    
def _score_data(unsorted_data):
    scores = {}
    for key, data in unsorted_data.items():
        out_elms = 0
        in_elms = 0
        if data.strip() == '':
            scores[key] = 0
        else:            
            #compute: score = no.outgoung / no.incoming
            out_elms = _compute_out(data)
            in_elms = _compute_in(key, unsorted_data)
            scores[key] = np.inf if in_elms == 0 else (out_elms/in_elms)
        #print ("Key [{}], Out[{}], In[{}], Score[{}]".format(key, out_elms, in_elms, scores.get(key)))
    
    scores = dict(sorted(scores.items(), key=lambda item: item[1]))
    #print(scores)
    return scores
    
def _remove_best(unsorted_data, key, sorted_data, relations):
    for k, v in unsorted_data.items():
        if key in v:
            deps = v.split(',')
            dependents = deps.copy()
            for d in deps:
                if d.strip() == key:
                    dependents.remove(d)

                    #add the relation between this entry's key and the 'key', if record exists then append to it
                    rels = relations.get(k)
                    if rels:
                        relations[k] = rels + ',' + key
                    else:
                        relations[k] = key
            
            #dependents = list(filter(lambda d: d.strip() != key, dependents))
            unsorted_data[k] = ','.join(dependents)
            
    unsorted_data.pop(key, None)
    
def _remove_cyclic(unsorted_data, key, sorted_data, relations, cyclics):    
    #1) add the 'key' as one of the cyclic dependencies
    cyclics[key] = unsorted_data.get(key)
    #2) remove from those depend on the 'key', record their relations to it, and finally remove the 'key'
    _remove_best(unsorted_data, key, sorted_data, relations)
    #3) finally, add the 'key' as one of the sorted keys
    sorted_data.append(key)
    
def _sort(unsorted_data, sorted_data, relations, cyclics):
    scores = _score_data(unsorted_data)
        
    best_key = list(scores.keys())[0]
    best_val = list(scores.values())[0]
    if best_val == 0:
        #remove best[0] from unsorted_data
        _remove_best(unsorted_data, best_key, sorted_data, relations)
        sorted_data.append(best_key)
    else:
        print('CYCLIC detected!')
        _remove_cyclic(unsorted_data, best_key, sorted_data, relations, cyclics)
    
    return unsorted_data

# %%
def _add_row(df_logs, table, **kwargs):
    idx = df_logs.index[df_logs['table']==table]
    if len(idx):
        idx = idx[0]
        for key, value in kwargs.items():
            if isinstance(value, list):   
                value = ','.join(value)
            if key not in (['no_records', 'ref_tables']):
                if isinstance(value, int):
                    df_logs.at[idx, key] = value
                else:
                    df_logs.at[idx, key] = df_logs.iloc[idx][key] + ',' + value
            else:
                df_logs.at[idx, key] = value
    else:
        df_logs = df_logs.append({'table':table}, ignore_index=True)
    
    return df_logs

# %%
def _populate_graph(metas, sorted_data, relations, cyclics, df_logs, commit):
    for data in sorted_data:
        meta = metas[data]
        table = meta['table']
        df_logs = _add_row(df_logs, table)
        rels = relations.get(table)
        skip = cyclics.get(table)
        if rels:
            #joined
            df_logs = generate_joined_graph(meta, skip, df_logs, commit)
        else:
            #single
            df_logs = generate_single_graph(meta, df_logs, commit)
    
    #create relation for cyclic references
    for table, refs in cyclics.items():
        meta = metas[table]
        df_logs = generate_edges(meta, refs, df_logs, commit)
        
    return df_logs

# %%
def _print(tables, metas, sorted_data, relations, cyclics):
    
    df_print1 = pd.DataFrame(columns=['table', 'ref_tables'])
    sep = '---------------'
    for table in tables:
        m = metas[table]
        ref_tables = m.get('ref_tables')
        rels = ref_tables.split(',')
        if ref_tables == '':
            rels = None            
        df_print1 = df_print1.append({'table':table, 'ref_tables':rels}, ignore_index=True)    
    df_print1 = df_print1.append({'table':sep, 'ref_tables':sep}, ignore_index=True)
    
    df_print2 = pd.DataFrame(columns=['table', 'ref_tables'])
    
    for data in sorted_data:
        meta = metas[data]
        table = meta['table']
        rs = relations.get(table)
        rels = None
        if rs:
            rels = rs.split(',')
        cs = cyclics.get(table)
        skip = None
        if cs:
            skip = cs.split(',')
        if skip and rels:
            rels = [i for i in rels if i not in skip]
        df_print2 = df_print2.append({'table':table, 'ref_tables':rels}, ignore_index=True)
    df_print2 = df_print2.append({'table':sep, 'ref_tables':sep}, ignore_index=True)
        
    df_print3 = pd.DataFrame(columns=['table', 'ref_tables'])
    for table, refs in cyclics.items():
        df_print3 = df_print3.append({'table':table, 'ref_tables':refs}, ignore_index=True)
    df_print3 = df_print3.append({'table':sep, 'ref_tables':sep}, ignore_index=True)
    
    df_print = df_print1.append(df_print2).append(df_print3)
    display(df_print)

# %%
def _generate_graph(df_logs, commit):
    q1 = ("SHOW TABLES FROM " + schema)
    c1 = connection.cursor(dictionary=True, buffered=True)
    c1.execute(q1)

    table_list = c1.fetchall()
    tables = []
    metas = {}
    unsorted_data = {}
    for entry in table_list:
        _, table = entry.popitem()
        tables.append(table)
        meta = get_metadata(c1, table)
        metas[table]=meta
        unsorted_data[meta.get('table')] = meta.get('ref_tables')
    
    sorted_data = []
    relations = {}
    cyclics = {}
    half_sort = dict(sorted(unsorted_data.items(), key=lambda item: item[1]))
    while True:
        half_sort = _sort(half_sort, sorted_data, relations, cyclics)
        if (len(half_sort) == 0):
            break

    _print(tables, metas, sorted_data, relations, cyclics)
    
    return _populate_graph(metas, sorted_data, relations, cyclics, df_logs, commit)

# %%
def cek_graph(df_logs):
    for table in df_logs['table']:
        query = f'MATCH (n:{table.capitalize()}) RETURN count(n) as total'
        total = 0
        idx = df_logs.index[df_logs['table']==table][0]

        total = neoConn.query(query)
        df_logs.at[idx,'no_nodes'] = total[0][0]
        
        rt = df_logs.iloc[idx]['ref_tables']
        if len(rt)>0:
            ref_tables = rt.split(',')
            ref_tables = list(dict.fromkeys(ref_tables))
            total = 0
            for rt in ref_tables:
                key = f'{table}_{rt}'.upper()
                query = f'MATCH p=()-[r:{key}]->() RETURN count(p) as total'
                tot = neoConn.query(query)[0][0]
                total = total + tot
            df_logs.at[idx,'no_edges'] = total
            
    df_logs.loc['total']= df_logs.sum()
    df_logs.loc[df_logs.index[-1], 'table'] = ''
    df_logs.loc[df_logs.index[-1], 'ref_tables'] = ''

# %%
import time
commit = False

start_time = time.time()

_clear_all(commit)

elapsed_time = time.time() - start_time
print('Execution time:', time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))

start_time = time.time()

_sorted = []

df_logs = pd.DataFrame(columns=['table', 'ref_tables', 'no_records', 'no_rels', 'no_nodes', 'no_edges'])
df_logs = _generate_graph(df_logs, commit)

cek_graph(df_logs)

elapsed_time = time.time() - start_time
print('Execution time:', time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
df_logs
# Out:
# Execution time: 00:00:00
# CYCLIC detected!
# CYCLIC detected!
#              table            ref_tables
# 0        customers           [employees]
# 1        employees  [employees, offices]
# 2          offices                  None
# 3     orderdetails    [orders, products]
# 4           orders           [customers]
# 5         payments           [customers]
# 6     productlines                  None
# 7         products        [productlines]
# 8  ---------------       ---------------
# 0          offices                  None
# 1     productlines                  None
# 2         products        [productlines]
# 3        customers                  None
# 4           orders           [customers]
# 5         payments           [customers]
# 6     orderdetails    [products, orders]
# 7        employees             [offices]
# 8  ---------------       ---------------
# 0        customers             employees
# 1        employees             employees
# 2  ---------------       ---------------
# ===> Processing records for Table 'offices'
# {'table': 'offices', 'pri_key': 'officeCode', 'for_keys': '', 'ref_tables': '', 'ref_keys': ''}
# table[offices], records[7]
# key[ref_tables], value[]
# key[no_records], value[7]
# key[no_rels], value[0]
# key[no_nodes], value[1]
# UNWIND $rows AS row
# CREATE (offices:Offices{officeCode: row.officeCode,city: row.city,phone: row.phone,addressLine1: row.addressLine1,addressLine2: row.addressLine2,state: row.state,country: row.country,postalCode: row.postalCode,territory: row.territory})
# RETURN count(*) as total
#
#
# ===> Processing records for Table 'productlines'
# {'table': 'productlines', 'pri_key': 'productLine', 'for_keys': '', 'ref_tables': '', 'ref_keys': ''}
# table[productlines], records[7]
# key[ref_tables], value[]
# key[no_records], value[7]
# key[no_rels], value[0]
# key[no_nodes], value[1]
# UNWIND $rows AS row
# CREATE (productlines:Productlines{productLine: row.productLine,textDescription: row.textDescription,htmlDescription: row.htmlDescription,image: row.image})
# RETURN count(*) as total
#
#
# ===> Processing records for Table 'products'
# {'table': 'products', 'pri_key': 'productCode', 'for_keys': 'productLine', 'ref_tables': 'productlines', 'ref_keys': 'productLine'}
# Processing reference Table 'productlines' ...
# key[ref_tables], value[['productlines']]
# key[no_records], value[110]
# key[no_rels], value[1]
# key[no_nodes], value[1]
# key[no_edges], value[1]
# UNWIND $rows AS row
# CREATE (products:Products{productCode: row.productCode,productName: row.productName,productLine: row.productLine,productScale: row.productScale,productVendor: row.productVendor,productDescription: row.productDescription,quantityInStock: row.quantityInStock,buyPrice: row.buyPrice,MSRP: row.MSRP})
#
# WITH distinct row, products
# UNWIND row.productLine AS _productLine
# MATCH (productlines:Productlines {productLine: _productLine})
# MERGE (products)-[:PRODUCTS_PRODUCTLINES]->(productlines)
# RETURN count(*) AS total
#
#
# ===> Processing records for Table 'customers'
# {'table': 'customers', 'pri_key': 'customerNumber', 'for_keys': 'salesRepEmployeeNumber', 'ref_tables': 'employees', 'ref_keys': 'employeeNumber'}
# table[customers], records[122]
# key[ref_tables], value[]
# key[no_records], value[122]
# key[no_rels], value[0]
# key[no_nodes], value[1]
# UNWIND $rows AS row
# CREATE (customers:Customers{customerNumber: row.customerNumber,customerName: row.customerName,contactLastName: row.contactLastName,contactFirstName: row.contactFirstName,phone: row.phone,addressLine1: row.addressLine1,addressLine2: row.addressLine2,city: row.city,state: row.state,postalCode: row.postalCode,country: row.country,salesRepEmployeeNumber: row.salesRepEmployeeNumber,creditLimit: row.creditLimit})
# RETURN count(*) as total
#
#
# ===> Processing records for Table 'orders'
# {'table': 'orders', 'pri_key': 'orderNumber', 'for_keys': 'customerNumber', 'ref_tables': 'customers', 'ref_keys': 'customerNumber'}
# Processing reference Table 'customers' ...
# key[ref_tables], value[['customers']]
# key[no_records], value[326]
# key[no_rels], value[1]
# key[no_nodes], value[1]
# key[no_edges], value[1]
# UNWIND $rows AS row
# CREATE (orders:Orders{orderNumber: row.orderNumber,orderDate: row.orderDate,requiredDate: row.requiredDate,shippedDate: row.shippedDate,status: row.status,comments: row.comments,customerNumber: row.customerNumber})
#
# WITH distinct row, orders
# UNWIND row.customerNumber AS _customerNumber
# MATCH (customers:Customers {customerNumber: _customerNumber})
# MERGE (orders)-[:ORDERS_CUSTOMERS]->(customers)
# RETURN count(*) AS total
#
#
# ===> Processing records for Table 'payments'
# {'table': 'payments', 'pri_key': 'customerNumber,checkNumber', 'for_keys': 'customerNumber', 'ref_tables': 'customers', 'ref_keys': 'customerNumber'}
# Processing reference Table 'customers' ...
# key[ref_tables], value[['customers']]
# key[no_records], value[273]
# key[no_rels], value[1]
# key[no_nodes], value[1]
# key[no_edges], value[1]
# UNWIND $rows AS row
# CREATE (payments:Payments{customerNumber: row.customerNumber,checkNumber: row.checkNumber,paymentDate: row.paymentDate,amount: row.amount})
#
# WITH distinct row, payments
# UNWIND row.customerNumber AS _customerNumber
# MATCH (customers:Customers {customerNumber: _customerNumber})
# MERGE (payments)-[:PAYMENTS_CUSTOMERS]->(customers)
# RETURN count(*) AS total
#
#
# ===> Processing records for Table 'orderdetails'
# {'table': 'orderdetails', 'pri_key': 'orderNumber,productCode', 'for_keys': 'orderNumber,productCode', 'ref_tables': 'orders,products', 'ref_keys': 'orderNumber,productCode'}
# Processing reference Table 'orders' ...
# Processing reference Table 'products' ...
# key[ref_tables], value[['orders', 'products']]
# key[no_records], value[2996]
# key[no_rels], value[2]
# key[no_nodes], value[1]
# key[no_edges], value[2]
# UNWIND $rows AS row
# CREATE (orderdetails:Orderdetails{orderNumber: row.orderNumber,productCode: row.productCode,quantityOrdered: row.quantityOrdered,priceEach: row.priceEach,orderLineNumber: row.orderLineNumber})
#
# WITH distinct row, orderdetails
# UNWIND row.orderNumber AS _orderNumber
# MATCH (orders:Orders {orderNumber: _orderNumber})
# MERGE (orderdetails)-[:ORDERDETAILS_ORDERS]->(orders)
# WITH distinct row, orderdetails
# UNWIND row.productCode AS _productCode
# MATCH (products:Products {productCode: _productCode})
# MERGE (orderdetails)-[:ORDERDETAILS_PRODUCTS]->(products)
# RETURN count(*) AS total
#
#
# ===> Processing records for Table 'employees'
# {'table': 'employees', 'pri_key': 'employeeNumber', 'for_keys': 'reportsTo,officeCode', 'ref_tables': 'employees,offices', 'ref_keys': 'employeeNumber,officeCode'}
# ********** Table 'employees' is a cyclic referenced by Table 'employees'..skipped it *********
# Processing reference Table 'offices' ...
# key[ref_tables], value[['employees', 'offices']]
# key[no_records], value[23]
# key[no_rels], value[2]
# key[no_nodes], value[1]
# key[no_edges], value[1]
# UNWIND $rows AS row
# CREATE (employees:Employees{employeeNumber: row.employeeNumber,lastName: row.lastName,firstName: row.firstName,extension: row.extension,email: row.email,officeCode: row.officeCode,reportsTo: row.reportsTo,jobTitle: row.jobTitle})
#
# WITH distinct row, employees
# UNWIND row.officeCode AS _officeCode
# MATCH (offices:Offices {officeCode: _officeCode})
# MERGE (employees)-[:EMPLOYEES_OFFICES]->(offices)
# RETURN count(*) AS total
#
#
# ===> Creating additional Edges between Table 'customers' and Table(s) 'employees'
# {'table': 'customers', 'pri_key': 'customerNumber', 'for_keys': 'salesRepEmployeeNumber', 'ref_tables': 'employees', 'ref_keys': 'employeeNumber'}
# employees
# Creating an Edge from Table 'customers' --> Table 'employees' ...
# key[ref_tables], value[['employees']]
# key[no_records], value[122]
# key[no_rels], value[1]
# key[no_edges], value[1]
# UNWIND $rows AS row
# UNWIND row.customerNumber AS _customerNumber
# MATCH (customers:Customers {customerNumber: _customerNumber})
# WITH distinct row, customers
# UNWIND row.salesRepEmployeeNumber AS _salesRepEmployeeNumber
# MATCH (employees:Employees {employeeNumber: _salesRepEmployeeNumber})
# MERGE (customers)-[:CUSTOMERS_EMPLOYEES]->(employees)
# RETURN count(*) AS total
#
#
# ===> Creating additional Edges between Table 'employees' and Table(s) 'employees'
# {'table': 'employees', 'pri_key': 'employeeNumber', 'for_keys': 'reportsTo,officeCode', 'ref_tables': 'employees,offices', 'ref_keys': 'employeeNumber,officeCode'}
# employees
# Creating an Edge from Table 'employees' --> Table 'employees' ...
# ********** Skipping table offices **********
# key[ref_tables], value[['employees', 'offices']]
# key[no_records], value[23]
# key[no_rels], value[2]
# key[no_edges], value[1]
# UNWIND $rows AS row
# UNWIND row.employeeNumber AS _employeeNumber
# MATCH (employees:Employees {employeeNumber: _employeeNumber})
# WITH distinct row, employees
# UNWIND row.reportsTo AS _reportsTo
# MATCH (employees_:Employees {employeeNumber: _reportsTo})
# MERGE (employees)-[:EMPLOYEES_EMPLOYEES]->(employees_)
# RETURN count(*) AS total
# Execution time: 00:00:00
#               table         ref_tables no_records no_rels no_nodes no_edges
# 0           offices                             7       0        0      NaN
# 1      productlines                             7       0        0      NaN
# 2          products       productlines        110       1        0        0
# 3         customers          employees        122       1        0        0
# 4            orders          customers        326       1        0        0
# 5          payments          customers        273       1        0        0
# 6      orderdetails    orders,products       2996       2        0        0
# 7         employees  employees,offices         23       2        0        0
# total                                        3864       8        0        0
